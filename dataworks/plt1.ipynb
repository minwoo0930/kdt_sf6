# %% [markdown]
# ### 시각화 라이브러리 사용 -Matplotlib

# %%
import matplotlib.pyplot as plt 

plt.title("Basic Graph")  # 그래프 이름 출력 
#plt.plot([1, 2, 3, 4]) # 값이 하나만 입력되면 Y축 값이 입력된다. 
plt.plot([1,2,3,4],[10, 40, 20, 30])# plt(가로(x)축 값, 세로(Y)축 값)
plt.show() # 시각화 출력

# %%
import matplotlib.pyplot as plt 

plt.rc('font', family = 'Malgun Gothic')
plt.title("시험 성적 그래프", pad =10, loc = "right") # pad(패딩) - 여백, 10 -> 10px # 그래프 이름 출력   
#plt.plot([1, 2, 3, 4]) # 값이 하나만 입력되면 Y축 값이 입력된다. 
plt.plot([1,2,3,4],[90, 80, 85, 70])# plt(가로(x)축 값, 세로(Y)축 값)
plt.xlabel("학생번호")# 한국어로 하면 안됨 -> plt.rc 함수로 한글 글꼴 명시해야함/ x축 제목 기입 함수 
plt.ylabel("시험점수")# y축 제목 기입 함수 

# 격자 형태 
axis = {'both', 'x', 'y'}

#plt.grid() #default - 가로, 세로 표시 
plt.grid(True, axis ='both')
plt.show() # 시각화 출력

# %%
import matplotlib.pyplot as plt 

plt.rc('font', family = 'Malgun Gothic')
plt.title("범례 및 색상 표시")# 그래프 이름 출력   
plt.plot([10,20,30,40], label = "circle", color= 'r') #범례 표시(label = ""), 컬러 표시(color = "")
plt.plot([40,30,20,10], label = "triangle", color= 'g') 
plt.legend() #범례(소제목)를 표시할 때 반드시 필요한 함수 -> 없으면 범례 표시 안됨 
plt.show() # 시각화 출력
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_15568\634140807.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot([10,20,30,40], 'b', label = "circle", color= 'r') #범례 표시(label = ""), 컬러 표시(color = "")

# %%
import matplotlib.pyplot as plt 

plt.rc('font', family = 'Malgun Gothic')
plt.title("범례 및 색상 표시")# 그래프 이름 출력   
plt.plot([10,20,30,40], 'b.', label = "circle") # 'b.' -> 파란색 동그라미 마커를 의미 
plt.plot([40,30,20,10], 'r^', label = "triangle") #'r^' -> 빨간색 삼각형 마커를 의미 
plt.legend() #범례(소제목)를 표시할 때 반드시 필요한 함수 -> 없으면 범례 표시 안됨 
plt.show() # 시각화 출력

# %%
import matplotlib.pyplot as plt 

#x = [0,1,2,3,4,5] # 막대 그래프의 x축 
y = [1,2,3,5,6,7] # 막대 그래프의 y축 

# x = range(6)
print(x)

plt.bar(range(6), y) #bar() -> 막대 그래프 
plt.show()

# %%
import matplotlib.pyplot as plt 

#x = [0,1,2,3,4,5] # 막대 그래프의 x축 
y = [100,200,300] # 막대 그래프의 y축 

# 세로 막대 그래프
plt.bar(range(3), y, color = ['r', 'g', 'b'], width = 0.6) #bar() -> 막대 그래프 

# 눈금 표시 
plt.xticks(x, ['2018', '2019', '2020'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 10
#       7 plt.bar(range(3), y, color = ['r', 'g', 'b'], width = 0.6) #bar() -> 막대 그래프
#       9 # 눈금 표시
# ---> 10 plt.xticks(x, ['2018', '2019', '2020'])
#      11 plt.show()
#
# File C:\anaconda\Lib\site-packages\matplotlib\pyplot.py:2068, in xticks(ticks, labels, minor, **kwargs)
#    2066         l._internal_update(kwargs)
#    2067 else:
# -> 2068     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2070 return locs, labels_out
#
# File C:\anaconda\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# ...

# %%
# 가로 막대(수평 막대) 그래프 
import matplotlib.pyplot as plt 

X = range(3)
y = [100,400,900] # 막대 그래프의 y축 

# 세로 막대 그래프
plt.barh(y,rane(3), color = ['r', 'g', 'b'], width = 0.6) #bar() -> 막대 그래프 

# 눈금 표시 
plt.xticks(x, ['2018', '2019', '2020'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5 y = [100,400,900] # 막대 그래프의 y축
#       7 # 세로 막대 그래프
# ----> 8 plt.barh(y,rane(3), color = ['r', 'g', 'b'], width = 0.6) #bar() -> 막대 그래프
#      10 # 눈금 표시
#      11 plt.xticks(x, ['2018', '2019', '2020'])
#
# NameError: name 'rane' is not defined
